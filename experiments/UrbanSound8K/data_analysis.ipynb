# %%
import IPython.display as idp
import librosa

# %%
audio, rt = librosa.load('data/audio/fold5/17578-5-0-1.wav', sr=22050, mono=True,  res_type='kaiser_fast')
idp.Audio(audio, rate=rt)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio, rt = librosa.load('data/audio/fold5/17578-5-0-1.wav', sr=22500, mono=True,  res_type='kaiser_fast')
idp.Audio(audio, rate=rt)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio, rt = librosa.load('data/audio/fold5/17578-5-0-6.wav', sr=8000, mono=True,  res_type='kaiser_fast')
idp.Audio(audio, rate=rt)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio, rt = librosa.load('data/audio/fold5/178825-2-0-53.wav', sr=8000, mono=True,  res_type='kaiser_fast')
idp.Audio(audio, rate=rt)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
